# %%
import os

# %%
os.chdir(r'C:\Users\RAHUL\Desktop\DS_Monali\python\exam')

# %%
fhand = open('Exam.txt',encoding = 'utf8')
for line in fhand:
    line=line.strip() 
    print(line)
# Out:
# 1/31/22, 15:49 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 1/31/22, 15:42 - Anushya Mahe Praxis created group "PGPDS Jan'22 - BLR "
# 1/31/22, 15:49 - +91 98319 48077 added you
# 1/31/22, 15:52 - +91 70592 29103 joined using this group's invite link
# 1/31/22, 15:53 - Praxis Bhaskar joined using this group's invite link
# 1/31/22, 15:53 - +91 70592 29103 left
# 1/31/22, 15:53 - +91 96740 67641 joined using this group's invite link
# 1/31/22, 15:54 - +91 94836 22622 joined using this group's invite link
# 1/31/22, 15:55 - +91 97429 97747 joined using this group's invite link
# 1/31/22, 15:56 - +91 97906 93577 joined using this group's invite link
# 1/31/22, 15:56 - +91 6206 308 339 joined using this group's invite link
# 1/31/22, 15:56 - +91 98316 71628 joined using this group's invite link
# 1/31/22, 15:57 - +91 79905 19874 joined using this group's invite link
# 1/31/22, 15:57 - +91 88484 35019 joined using this group's invite link
# 1/31/22, 15:58 - +91 97176 71005 joined using this group's invite link
# 1/31/22, 15:59 - +91 79762 49627 joined using this group's invite link
# 1/31/22, 16:03 - +91 96656 60920 joined using this group's invite link
# 1/31/22, 16:04 - +91 87575 13131 joined using this group's invite link
# 1/31/22, 16:04 - +91 97736 87548 joined using this group's invite link
# 1/31/22, 16:05 - +91 79760 59601 joined using this group's invite link
# 1/31/22, 16:06 - +91 98316 71628 added +91 98608 68194
# 1/31/22, 16:06 - +91 98316 71628 added +91 70342 08214
# 1/31/22, 16:07 - +91 98316 71628 added +91 97269 95920
# 1/31/22, 16:07 - +91 98316 71628 added +91 90796 99645
# 1/31/22, 16:09 - +91 75054 04417 joined using this group's invite link
# 1/31/22, 16:09 - +91 98316 71628 added +91 98781 01877
# 1/31/22, 16:09 - Anushya Mahe Praxis: Hello all welcome to praxis Bangalore group - Myself Anushya from admissions team
# 1/31/22, 16:11 - Anushya Mahe Praxis: This is the official group for all the Bangalore students. So, Kindly everyone introduce yourself
# Thank you
# 1/31/22, 16:11 - Praxis Madhuri Praxis Business School: Hi everyone.. Welcome to Praxis
# 1/31/22, 16:13 - +91 99788 89134 joined using this group's invite link
# 1/31/22, 16:15 - +91 95400 00588 joined using this group's invite link
# 1/31/22, 16:16 - +91 98316 71628 added +91 94725 96200
# 1/31/22, 16:16 - +91 98319 48077 added +91 98517 08183
# 1/31/22, 16:20 - +91 98316 71628 removed +91 98517 08183
# 1/31/22, 16:21 - +91 88846 30027 joined using this group's invite link
# 1/31/22, 16:28 - +91 97736 87548: Hi everyone!  I am Aanchal and I am from Gurgaon. I worked as a teacher, but I am equally excited about being a student again :) Looking forward to meeting you all on campus, hopefully soon!
# 1/31/22, 16:30 - +91 88600 61135 joined using this group's invite link
# 1/31/22, 16:30 - +91 6206 308 339: Hi everyone! I am Abhishek Anand Lal. I did graduation in BTech and have an experience of 14 months. Excited to join the campus and Looking forward to see you all in the campus.
# 1/31/22, 17:02 - +91 75054 04417: Because while engineering we learn how to tackle problems and live life
# 1/31/22, 17:03 - +91 99788 89134: That’s what he said :p
# 1/31/22, 17:03 - Anushya Mahe Praxis: Guys use this group only for official purpose so kindly give your introduction
# 1/31/22, 17:04 - +91 75054 04417: #days before exams
# 1/31/22, 17:04 - +91 75054 04417: ✌️
# 1/31/22, 17:04 - +91 98316 71628: Hello Everyone, Sangeeta here from Praxis Admissions Team🤚
# 1/31/22, 17:04 - +91 97736 87548: Oh sorry - didn’t know that!
# 1/31/22, 17:05 - +91 98316 71628: Rather would suggest, why don't you create a seperate group adding all from your batch and start chatting😀
# 1/31/22, 17:05 - Anushya Mahe Praxis: Exactly
# 1/31/22, 17:05 - +91 97736 87548: yes, fabulous idea. I’ll share the link here
# 1/31/22, 17:06 - Anushya Mahe Praxis: This group will be used for your class links and few more official purposes only
# 1/31/22, 17:06 - +91 98316 71628: Someone takes up the initiative and do the needful
# 1/31/22, 17:06 - +91 87575 13131: <Media omitted>
# 1/31/22, 17:07 - +91 87575 13131: ‎Open this link to join my WhatsApp Group: https://chat.whatsapp.com/DcW7RnmvKklCO40WMYULNs
# 1/31/22, 17:07 - +91 87575 13131: All the fellow classmates…
# Join this!
# 1/31/22, 17:08 - +91 97736 87548: Thank you!!
# 1/31/22, 17:08 - +91 87575 13131: Anytime…
# 1/31/22, 17:09 - +91 98316 71628: That's better @918757513131 👍
# 1/31/22, 17:10 - Anushya Mahe Praxis: That's okay
# 1/31/22, 17:25 - +91 94447 66219 joined using this group's invite link
# 1/31/22, 17:27 - +91 820 937 3714 joined using this group's invite link
# 1/31/22, 17:27 - +91 90512 71875 joined using this group's invite link
# 1/31/22, 17:28 - +91 92233 84466 joined using this group's invite link
# 1/31/22, 17:28 - +91 87575 13131 changed the group description
# 1/31/22, 17:38 - Praveena Vinod: Dear students,
#
# Please check your schedule for the term - I updated it in KK2 . Please find the Link  Here.
# 1/31/22, 17:38 - Praveena Vinod: http://kk2.praxis.ac.in/p/blog-page.html
# 1/31/22, 18:05 - +91 97429 97747: Hi everyone, I'm Akhila. I am from commerce stream with experience in market reporting and customer domain. All the best🙂
# 1/31/22, 18:17 - +91 97269 95920: All the best to you too
# 1/31/22, 19:05 - +91 70301 03636 joined using this group's invite link
# 1/31/22, 19:48 - +91 80790 25956 joined using this group's invite link
# 1/31/22, 23:42 - +91 95400 00588: Hi everyone🙋🏻‍♂️,
# Akshay this side. I am a chemical engineering graduate with work ex in project management domain.
# Looking forward to meet you in person soon 😊
# 2/1/22, 02:23 - Praxis Bhaskar: Hi Everyone, Bhaskar here from Delhi. I'm a CS graduate with few years of work ex in IT industry.
# Hope to meet you all very soon!
# 2/1/22, 13:21 - +91 70192 55442 joined using this group's invite link
# 2/1/22, 13:22 - +91 70192 55442 left
# 2/2/22, 12:58 - Praveena Vinod: Hi Evereyone,
# 2/2/22, 12:59 - Praveena Vinod: Dear Students,
# Kindly go through the documents attached to understand better the steps to be followed to complete your registration process.
# In case of any query please write at praveena@praxis.ac.in or call me at 6360155028 (week days between 10 a.m to 5 p.m)
# 2/2/22, 12:59 - Praveena Vinod: <Media omitted>
# 2/2/22, 13:01 - Praveena Vinod: Please find below the google classroom link to upload the documents https://classroom.google.com/c/NDYzNjc4MTAxMDM2/a/NDYzODEwMjk5MDQ1/details
# 2/2/22, 13:01 - Praveena Vinod: always use Praxis Email ID to access the emails and to attend classes
# 2/2/22, 13:01 - Praveena Vinod: Any queries , Please call me or message me
# 2/2/22, 13:31 - +91 98316 71628 added +91 96014 18197
# 2/2/22, 13:32 - +91 98316 71628: Welcome Swati to the Bengaluru Batch.
# 2/2/22, 13:33 - +91 96014 18197: Thank you so much
# 2/2/22, 13:33 - +91 98316 71628: Guys Swati has joined your batch from today. Please give a warm welcome. Also, kindly introduce yourself Swati.
# 2/2/22, 13:34 - +91 96014 18197: Hello everyone, i am new to the batch. I graduated in 2015 as a electronic and communication engineer. I bring 3.5 years of work experience. I am from Gujarat, Vadodara
# 2/2/22, 14:22 - +91 99463 51164: Great to meet you
# 2/2/22, 14:58 - +91 96014 18197: Thank you
# 2/2/22, 15:34 - Praveena Vinod: Hi Swati , Your Praxis Email credentials will be shared with you shortly to your personal Email ID please
# 2/2/22, 15:35 - +91 96014 18197: Okay
# 2/2/22, 15:41 - Praveena Vinod: Swati i have shared a registration form kindly fill the form
# 2/2/22, 15:42 - +91 96014 18197: Yes
# 2/2/22, 16:03 - +91 75054 04417: Hello ma'am,  is there any update on opening of college since the Kolkata campus is opening from 14th Feb?
# 2/2/22, 16:04 - Praveena Vinod: Will update you by email
# 2/3/22, 11:15 - +91 820 937 3714: Where would i find MOP undertaking?
# 2/3/22, 11:16 - Praveena Vinod: Will have mop overview on 4th then will share the mop with you
# 2/3/22, 11:16 - +91 820 937 3714: Ok
# 2/3/22, 13:33 - Sushanta Praxis: Hello All,
# 2/3/22, 13:33 - Sushanta Praxis: Hope you all are enjoying your orientation classes
# 2/3/22, 13:39 - Sushanta Praxis: You all need to talk amongst yourself and nominate 2 candidates for CR
# 2/3/22, 13:39 - Sushanta Praxis: Out of the 2, 1 would be selected as CR
# 2/3/22, 13:40 - Sushanta Praxis: You all need to share the names by today
# 2/3/22, 14:01 - +91 75054 04417: @919878101877 and @918860061135
# 2/3/22, 14:01 - +91 98781 01877: 👍🏻
# 2/3/22, 14:02 - Sushanta Praxis: Who is 8860061135
# 2/3/22, 14:02 - +91 75054 04417: Savi Wilson
# 2/3/22, 14:02 - +91 88600 61135: Savi Wilson..this side
# 2/3/22, 14:02 - Sushanta Praxis: Great
# 2/3/22, 14:03 - +91 98781 01877: This is Arav mam.
# 2/3/22, 14:05 - Sushanta Praxis: I am not female 😄😄 If i correctly remember many of you had talked with me
# 2/3/22, 14:14 - Sushanta Praxis: Another piece of good news to share... Karnataka Government has permitted to reopen colleges in Karnataka
# 2/3/22, 14:14 - +91 88600 61135: Wow 😊
# 2/3/22, 14:14 - +91 97736 87548: That's great news!
# 2/3/22, 14:14 - +91 95400 00588: 👌👌
# 2/3/22, 14:17 - +91 97736 87548: When will be hearing about the opening date, Sir?
# 2/3/22, 14:17 - Sushanta Praxis: Very soon
# 2/3/22, 14:18 - +91 98781 01877: Sorry sir i thought it was praveena mam
# 2/3/22, 14:20 - Sushanta Praxis: No issues
# 2/3/22, 14:21 - +91 94836 22622: This message was deleted
# 2/3/22, 14:22 - +91 94836 22622: Sir, could you please confirm if you would be informing us few weeks in advance ?
# 2/3/22, 14:22 - Sushanta Praxis: Yes we would give ample time
# 2/3/22, 14:22 - +91 94836 22622: Thank you
# 2/3/22, 14:23 - Sushanta Praxis: We would also add few of your Seniors in this group who help all of you on various info including accommodation
# 2/3/22, 14:23 - +91 97736 87548: Sir, does the admin maintain a list of  accommodation recommendations/contact information for out of state students?
# 2/3/22, 14:23 - +91 97736 87548: Yes please..that would be really heloful
# 2/3/22, 14:23 - +91 97736 87548: helpful*
# 2/3/22, 14:24 - Sushanta Praxis: Officialy, college would not suggest any accommodation info but your Seniors would definately share such info
# 2/3/22, 14:26 - Sushanta Praxis: Also each and everyone are requested to interact in this group
# 2/3/22, 14:41 - +91 98781 01877: Yes sir
# 2/3/22, 15:35 - +91 75054 04417: This message was deleted
# 2/3/22, 15:39 - +91 75054 04417: Sure sir.
# 2/3/22, 15:48 - Sushanta Praxis: We are going to declare the dates very shortly
# 2/3/22, 15:49 - Sushanta Praxis: And ample  time would be given to all to plan
# 2/3/22, 15:50 - +91 75054 04417: Sounds great, thanks for informing.
# 2/3/22, 15:57 - Sushanta Praxis: Arav and Savi, please create 2 gmeet links, 1 for 5 pm and the other for  530pm respectively and add gourab@praxis.ac.in and monika@praxis.ac.in
# 2/3/22, 15:58 - Sushanta Praxis: Arav you can take 5 pm slot and Savi 530
# 2/3/22, 15:58 - +91 88600 61135: Sure
# 2/3/22, 15:59 - Sushanta Praxis: Pls confirm once you are done with links
# 2/3/22, 16:02 - +91 98781 01877: Ok
# 2/3/22, 16:07 - +91 98781 01877: Done sir
# 2/3/22, 16:08 - +91 98781 01877: Monika mam is not available sir.
# 2/3/22, 16:10 - Sushanta Praxis: No issues Gourab would take it on
# 2/3/22, 16:19 - +91 88600 61135: It is done
# 2/4/22, 14:21 - Sushanta Praxis: Hello all, its time to declare your CR...
# 2/4/22, 14:25 - Sushanta Praxis: A CR has a big roll to play in terms batch integrity, well being, liaise with all relevant departments, bringing to our notice the problems faced by every students of the batch so that we can give address the problems and many more....
# 2/4/22, 14:28 - Sushanta Praxis: Am sure your CR would be strong enough to shoulder all the responsibilities and all of you as a batch and every  individual student would  attain Great Heights
# 2/4/22, 14:29 - Sushanta Praxis: Presenting you CR....
# 2/4/22, 14:29 - Sushanta Praxis: Savi Wilson
# 2/4/22, 14:30 - +91 96656 60920: Congratulations🥳
# 2/4/22, 14:30 - +91 88484 35019: Congrats @918860061135 ✌🏻💐
# 2/4/22, 14:30 - Sushanta Praxis: Savi Congratulations!!!
# 2/4/22, 14:30 - Sushanta Praxis: All our best wishes with you and with everyone
# 2/4/22, 14:30 - +91 95400 00588: Congratulations @918860061135 💐👍🏻
# 2/7/22, 12:43 - +91 88600 61135: Join again guys
# 2/7/22, 12:46 - +91 6206 308 339: Asking for meeting passcode
# 2/7/22, 12:46 - +91 97736 87548: Meeting ID:  959 6706 8362
# Passcode: dsjan@blr
# 2/7/22, 12:46 - +91 6206 308 339: Thanks
# 2/7/22, 13:10 - +91 94725 96200: There is a issue power cut in my area. .laptop goes down
# 2/7/22, 13:49 - Praveena Vinod: Please mail me for any issues
# 2/7/22, 15:12 - Praveena Vinod: Please join the MOP session now
# Join Zoom Meetinghttps://us06web.zoom.us/j/82145422411?pwd=K1V0L1liNElOQlJvZkJDTlJlMGVwZz09
# Meeting ID: 821 4542 2411
# Passcode: PGPDS21
# 2/7/22, 15:14 - Praveena Vinod: Please join the MOP session now
# Join Zoom Meeting
# https://us06web.zoom.us/j/82145422411?pwd=K1V0L1liNElOQlJvZkJDTlJlMGVwZz09
# Meeting ID: 821 4542 2411
# Passcode: PGPDS21
# 2/7/22, 15:17 - Praveena Vinod: Session started please join fast
# 2/7/22, 16:03 - Praveena Vinod: You deleted this message
# 2/7/22, 16:08 - Praveena Vinod: Dear Students please submit your documents online by today .
# 1.Akshay Lathwal
# 2.Akshay Raikar
# 3.Anmol Tripathi
# 4.Bhaskar
# 5.Hemin Vasani
# 6.Karthik G H
# 7.Nitin Kumar
# 8.Pranav Raj
# 9.Prathmesh
# 10.Savi
# 11.Shamsan
# 2/7/22, 16:08 - +91 88600 61135: Ma'am I have already uploaded
# 2/7/22, 16:10 - +91 95400 00588: Will do by EOD for sure.
# 2/7/22, 16:10 - Praveena Vinod: k
# 2/7/22, 16:11 - Praveena Vinod: k
# 2/7/22, 16:17 - Praxis Bhaskar: Sure Mam, will be completed
# 2/7/22, 16:18 - Praveena Vinod: You deleted this message
# 2/7/22, 16:19 - Praveena Vinod: 1.Akshay Lathwal
# 2.Akshay Raikar
# 3.Anmol Tripathi
# 4.Bhaskar
# 5.Hemin Vasani
# 6.Karthik G H
# 7.Nitin Kumar
# 8.Pranav Raj
# 9.Prathmesh
# 10.Savi
# 11.Shamsan
# 12.Gopal
# 13.Karan
# 14.Kushal
# 15.Shriya
# 16.Suparna
# Please students submit your photographs
# 2/7/22, 16:22 - +91 97411 21674: I have also uploaded mam
# 2/7/22, 16:34 - Praveena Vinod: K thank you
# 2/8/22, 08:32 - +91 75054 04417: Hello Praveena ma'am, we have a class from 8.30 and it has not started yet.
# 2/8/22, 08:32 - +91 75054 04417: Can you please look into it.
# 2/8/22, 08:35 - Praveena Vinod: Dear students,
# Faculty has joined
# 2/8/22, 10:16 - +91 97736 87548: Hello Ma'am, can you please add seniors on the group so that they can advise us about accommodation?
# 2/8/22, 10:17 - +91 97736 87548: Thank you!
# 2/8/22, 10:17 - Praveena Vinod: K Sushanta sir Will confirm to you kindly wait
# 2/8/22, 10:17 - +91 97736 87548: Sure Ma'am
# 2/8/22, 12:06 - Praveena Vinod: https://us06web.zoom.us/j/95967068362?pwd=SzdTczVJNmJFdWZFbWk1aW96aUlJZz09
# 2/8/22, 12:07 - Praveena Vinod: Please join the class
# 2/9/22, 12:27 - +91 6206 308 339: What is our roll no? It is asking in the form
# 2/9/22, 12:27 - +91 88600 61135: <Media omitted>
# 2/9/22, 12:28 - +91 6206 308 339: Thanks Savi
# 2/9/22, 16:52 - You're now an admin
# 2/9/22, 16:54 - Sushanta Praxis: Hello Praveena,  you have share the names of the students of the Senior batch, please include them in this group
# 2/9/22, 17:01 - You added Manisha Praxis and Preetham Vamsi
# 2/9/22, 17:03 - You added Priyanka G
# 2/9/22, 17:04 - You added Abishanth
# 2/10/22, 10:20 - +91 88600 61135: Hi Good Morning, I hope everyone from Jan'22 batch have uploaded the MOP undertaking in Google classroom. If not request you to do the same on priority basis. Thanks!
# 2/10/22, 10:20 - +91 75054 04417: Yes done.!!
# 2/10/22, 10:21 - +91 88600 61135: Additionally, Praveena Ma'am has added our seniors in this group to seek guidance on accommodation front. Request all to take it up here
# 2/10/22, 10:22 - +91 79762 49627: This message was deleted
# 2/10/22, 14:03 - +91 98319 48077 added Teja Sai
# 2/10/22, 14:03 - +91 98319 48077: Hi everyone...please welcome B.Teja to the Bengaluru Batch. He is joining from today.He has completed his B.tech from IIT Kharagpur.
# 2/10/22, 14:06 - +91 95150 92417: Hey Teja! Welcome 🎉
# 2/10/22, 14:12 - Teja Sai: Hello everyone, this is B. Teja Sai. Thank you for adding me to the group. Looking forward to the exciting world of Data Science and Business Analytics!
# 2/10/22, 14:12 - +91 98608 68194: Hi Teja ... welcome !🎊😀
# 2/10/22, 14:16 - +91 97736 87548: Welcome Teja! 😊
# 2/10/22, 14:41 - +91 96014 18197: Welcome Teja 🎉
# 2/10/22, 14:51 - +91 88600 61135: Welcome Teja 😊
# 2/10/22, 15:17 - +91 6206 308 339: Class is happening?
# 2/10/22, 15:21 - +91 97736 87548: yes..use the ID and passcode
# 2/10/22, 16:01 - +91 6206 308 339: Thanks Aanchal
# 2/10/22, 16:01 - +91 97736 87548: 👍🏼👍🏼
# 2/10/22, 17:03 - +91 88600 61135: Hi Praveena Ma'am, We have joined the meeting link for placement
# 2/10/22, 17:03 - +91 88600 61135: Waiting for the host
# 2/10/22, 17:04 - Praveena Vinod: 2 mins
# 2/10/22, 17:05 - Praveena Vinod: please wait
# 2/10/22, 17:08 - Praveena Vinod: Praxis is inviting you to a scheduled Zoom meeting.
#
# Topic: Praxis Data Science | Placement Sessions |
# Time: This is a recurring meeting Meet anytime
#
# Join Zoom Meeting
# https://us06web.zoom.us/j/82145422411?pwd=K1V0L1liNElOQlJvZkJDTlJlMGVwZz09
#
# Meeting ID: 821 4542 2411
# Passcode: PGPDS21
# 2/10/22, 17:08 - Praveena Vinod: any1 facing issues please join using this link
# 2/10/22, 17:11 - Praveena Vinod: students join fast
# 2/10/22, 17:12 - Praveena Vinod: its an important session pleasedont miss
# 2/11/22, 10:48 - Praveena Vinod: 1.Abhisehk Anand Lal
# 2.Anmol
# 3.Teja
# 4.Himkant
# 5.Keshav
# 6.Nitin
# 7.Pranav
# 8.Shamsan
# Student undertaking is still pending please complete it immediately
# 2/11/22, 10:49 - +91 75054 04417: Maam I have already submitted
# 2/11/22, 10:49 - +91 6206 308 339: I have done with that.
# 2/11/22, 10:50 - Praveena Vinod: Please redo its not showing
# 2/11/22, 10:51 - +91 75054 04417: Ok ma'am
# 2/11/22, 10:53 - Teja Sai: The Google form?
# 2/11/22, 10:57 - +91 75054 04417: Done maam
# 2/11/22, 13:07 - +91 87575 13131: Done ✅
# 2/11/22, 13:21 - +91 88600 61135: Hi Guys
#
# Request people who are interested to join Place com to share their details* to Hritik Vijay to his mail id which is hritik.vijay@praxis.ac.in
#
# *PFB details required from interested candidates
# Name
# LinkedIn profile
# Contact number
# 2/11/22, 13:28 - +91 88600 61135: Also, as intimated by Kolkata batch Praxis is organising a fest named "Spardha" on 24-25th Feb'22 through virtual mode.
#
# People who are interested in participating for singing, dancing or showcasing any other talent can contact Harendra (CR of Kol batch).
# Contact details: 8121107107
# 2/11/22, 13:53 - Teja Sai: I guess the 3:15 PM class is canceled. No more classes today right?
# 2/11/22, 14:25 - +91 6206 308 339: @918860061135 Is there no more class today?
# 2/11/22, 14:27 - +91 75054 04417: calendar is not showing i think.
# 2/11/22, 14:27 - +91 6206 308 339: Okay. Thanks
# 2/11/22, 14:27 - +91 88600 61135: Yes we dont have any classes today as per cancellation mail shared by Praveena ma'am
# 2/13/22, 15:34 - +91 88600 61135: Hi I can't figure out Yogesh Shakya's contact number
# 2/13/22, 15:35 - +91 88600 61135: Siddhi Sarda is inviting you to a scheduled Zoom meeting.
#
# Topic: placement interview
# Time: Feb 13, 2022 11:00 AM India
#
# Join Zoom Meeting
# https://zoom.us/j/93203985419?pwd=THRlY3VORjV0VWgxMHZNaUpUMGYwdz09
#
# Meeting ID: 932 0398 5419
# Passcode: r9kLC2
# 2/13/22, 15:36 - +91 88600 61135: Request Yogesh to join this link for place com interview by 3:45
# 2/13/22, 15:36 - +91 88600 61135: Today
# 2/13/22, 16:05 - +91 820 937 3714: Ok
# 2/15/22, 15:29 - You added Nimalan Praxis
# 2/16/22, 10:47 - Praveena Vinod: Please do not join late for the classes
# 2/16/22, 10:47 - Praveena Vinod: faculty is waiting
# 2/16/22, 10:48 - Praveena Vinod: join for the class now
# 2/16/22, 13:25 - Praveena Vinod: 1.Bhaskar
# 2.Abhishek Anand Lal
# 3.Nitin
# 4.Pranav
# 5.Shamsan
# please upload the documents online by today itself
# 2/16/22, 13:26 - Praveena Vinod: 1.Teja
# 2.Bhaskar
# 3.Karan
# 4.Kushal
# 5.Pranav
# 6.Savi wilson
# 7.Shamson
# Please upload the photograph in google classroom immediately . If already done please resend once more
# 2/16/22, 13:44 - +91 87575 13131: Done
# 2/16/22, 13:47 - +91 87575 13131: Done
# 2/16/22, 14:34 - +91 88600 61135: Hi All, Please fill this form for SQL as communicated by Saurabh sir in class.
#
# http://shorturl.at/rtACM
# 2/16/22, 14:35 - +91 99463 51164: Should we give the praxis mail id or personal mail?
# 2/16/22, 14:35 - +91 75054 04417: Both
# 2/16/22, 14:35 - +91 88600 61135: Personal
# 2/16/22, 14:37 - +91 88600 61135: Wait let me re confirm
# 2/17/22, 16:49 - You added Monali Sanjay Bendale
# 2/17/22, 16:49 - Praveena Vinod: Welcome Monali to the DS Spring group
# 2/17/22, 17:47 - +91 97736 87548: Hi Monali 😀
# 2/17/22, 18:03 - +91 95150 92417: Hey Monali 😄
# 2/17/22, 18:26 - Monali Sanjay Bendale: Hi all
# 2/18/22, 13:08 - Praveena Vinod: Dear Students,
#
# Please find The on campus class protocols details are attached herewith.
#
# Note
# Please carry your original Documents with 2 copies of passport size Photo.
#
#
#
# Any doubts , Please contact me .
#
# Regards
# Praveena J P
# 2/18/22, 13:08 - Praveena Vinod: You deleted this message
# 2/18/22, 13:09 - Praveena Vinod: <Media omitted>
# 2/18/22, 13:31 - +91 95150 92417: Okay ma'am. Thank you
# 2/18/22, 13:37 - +91 75054 04417: Thank you ma'am
# 2/18/22, 21:57 - Praxis Madhuri Praxis Business School left
# 2/21/22, 09:49 - Praveena Vinod: Students Please turn on your camera for the class or you will be marked absent
# 2/21/22, 10:05 - +91 820 937 3714: Ok
# 2/21/22, 10:06 - Teja Sai: Ok
# 2/22/22, 09:45 - Praveena Vinod: Hi Everyone ,
# 2/22/22, 09:45 - Praveena Vinod: Good Morning
# 2/22/22, 09:46 - +91 95400 00588: Hi, Good morning
# 2/22/22, 09:47 - Praveena Vinod: You deleted this message
# 2/22/22, 09:47 - Praveena Vinod: Today at 12.30 pm we have a Intro Session with the Bangalore Team . Kindly join using the below mentioned Link
# Join Zoom Meeting
# 2/22/22, 09:47 - Praveena Vinod: Join Zoom Meeting
# https://us06web.zoom.us/j/81207245164?pwd=Vnd1aEI0K0xLT1N1QXB1NkJyRURLUT09
#
# Meeting ID: 812 0724 5164
# Passcode: PGPDS22
# 2/22/22, 10:02 - Praveena Vinod: Students ,
# Kindly note that the session  timings is changed to 4.45 pm .
# 2/22/22, 15:32 - Praveena Vinod: Dear Students,
# Message me personally for your desired name in Praxis documents
# 2/23/22, 12:46 - Praveena Vinod: Important
# Dear Students,
# Message me personally for your desired name in Praxis documents . Please send me immediately
# 2/23/22, 15:02 - Praveena Vinod: Ajith P Augustine
# Akshay Lathwal
# Anmol Tripathi
# Arnab Mandal
# Karan Manot
# Karthik GH
# Keshav Chandra Singh Rathore
# Pranav Raj
# Prathmesh Dilip Morane
# Shimanshu Gera
# Yogesh Singh Shakya
# 2/23/22, 15:02 - Praveena Vinod: these students please your correct name for praxis documents immediately
# 2/23/22, 15:03 - Praveena Vinod: later will not change the name
# 2/24/22, 20:33 - Praveena Vinod: Dear students,
# Tomorrow all the sessions will be conducted in online mode only.
# 3/1/22, 10:44 - +91 88600 61135: Hi Everyone, We won’t be have IML class today
# 3/1/22, 10:45 - Praxis Aarti Madhavi: Ok
# Thanks savi
# 3/1/22, 10:45 - Praxis Aarti Madhavi: This message was deleted
# 3/1/22, 10:45 - Praxis Aarti Madhavi: So after 12.15 pm there's no lecture
# 3/1/22, 10:46 - +91 88600 61135: Yes
# 3/1/22, 11:24 - Praveena Vinod: Hi everyone,
# Today's IML session is cancelled. The session will be rescheduled to next week
# 3/2/22, 09:13 - Praveena Vinod: Dear students,
#
# Class will start in 15 mins,  kindly wait
# 3/2/22, 09:14 - Praveena Vinod: Faculty will start the class now online students kindly join
# 3/2/22, 16:08 - Praveena Vinod: You deleted this message
# 3/2/22, 16:10 - Praveena Vinod: Online students please join the link for Assignment discussion
#
# Join Zoom Meeting
# https://us06web.zoom.us/j/81207245164?pwd=Vnd1aEI0K0xLT1N1QXB1NkJyRURLUT09
#
# Meeting ID: 812 0724 5164
# Passcode: PGPDS22
# 3/2/22, 21:56 - Praveena Vinod: Tomorrow morning 8.30am MR session is canceled. Will reschedule in the next week.
# 3/2/22, 22:03 - +91 88600 61135: Ok
# 3/4/22, 10:57 - Praveena Vinod: classroom students please do not join zoom app
# 3/4/22, 11:12 - +91 88600 61135: Online students please join the zoom link
# 3/4/22, 11:12 - +91 88600 61135: The old one which is there on calendar
# 3/4/22, 15:20 - Praveena Vinod: Please wait DSP faculty will join in sometime
# 3/8/22, 09:36 - Sushanta Praxis: Happy Women's Day to all the women's in this Group...
# 3/8/22, 15:33 - +91 95150 92417: Thank you sir!
# 3/8/22, 17:46 - +91 88600 61135: Thank you soo much Sir😊
# 3/8/22, 18:33 - +91 96014 18197: Thank you sir 🙂
# 3/9/22, 09:07 - Praveena Vinod: You deleted this message
# 3/9/22, 11:26 - Praveena Vinod: You deleted this message
# 3/9/22, 11:27 - Praveena Vinod: Dear Students,
# Kindly note that today's Python class timings is changed to 3.15 - 4.45 pm
# 3/9/22, 11:42 - +91 95400 00588: Noted.
# 3/10/22, 10:36 - Praveena Vinod: Hi Everyone,
# Online students did you receive the Term1 books ? please ping me on my number
# 3/10/22, 12:34 - Praveena Vinod: Students , IML session will start by 12.45 pm
# 3/11/22, 19:56 - Praveena Vinod: Dear students,
# kindly share the feedback  I have shared the forms in Google classroom.
# 3/11/22, 20:04 - Praveena Vinod: Students RDWH assignment 1 few students are yet to submit kindly Sumit now
# 3/11/22, 20:29 - +91 95150 92417: Hi ma'am. The feed back forms are not any subject specific. Can you please sort it out
# @916360155028
# 3/11/22, 20:31 - Praveena Vinod: There are 8 forms please fill according to the courses
# 3/11/22, 20:31 - +91 95150 92417: Okay ma'am
# 3/12/22, 10:06 - Praveena Vinod: Dear students,
# Everyone kindly share the feedback  I have shared the forms in Google classroom course wise kindly share the feedback immediately .
# 3/12/22, 10:27 - +91 79905 19874: There is again an error in it as MML feedback is twice
# 3/12/22, 10:28 - Praveena Vinod: No error check again
# 3/12/22, 10:29 - Teja Sai: I think DVST is missing ma'am
# 3/12/22, 10:29 - Teja Sai: Instead, there are two MML forms
# 3/12/22, 10:30 - Teja Sai: Please rename one as DVST
# 3/12/22, 10:33 - Praveena Vinod: I have changed recheck
# 3/14/22, 10:06 - +91 88600 61135: Hi Good morning everyone, Request all students to come to college and settle down 15 mins prior exam start i.e 2:45pm.
# 3/14/22, 10:07 - +91 87575 13131: 👍
# 3/14/22, 10:19 - +91 75054 04417: Okay 👍
# 3/14/22, 10:21 - +91 95150 92417: Okay
# 3/14/22, 13:00 - Praveena Vinod: Please carry Praxis student ID card for exams . Its mandatory
# 4/1/22, 08:31 - +91 95400 00588: Good morning ma’am
# 4/1/22, 08:32 - Praveena Vinod: Please be present at 8.45am for the class. Do not come late,  you will not be allowed to attend the class.
# 4/1/22, 08:32 - +91 95150 92417: Good morning ma'am
# 4/1/22, 08:32 - +91 95400 00588: Noted.
# 4/2/22, 10:40 - Praveena Vinod: <Media omitted>
# 4/2/22, 10:40 - Praveena Vinod: <Media omitted>
# 4/2/22, 10:50 - +91 70301 03636: <Media omitted>
# 4/2/22, 11:07 - +91 96656 60920: Happy Ugadi & Happy Gudi Padwa✨😄
# 4/2/22, 11:10 - +91 98608 68194: Happy Ugadi n Happy Gudi Padwa!!
# 4/2/22, 11:17 - Monali Sanjay Bendale: A new hope, a new beginning, a new dream is waiting to unfold.
# May this Gudi Padwa bring your way millions of joys unheard – untold.
# 🎊🎊
# 4/2/22, 12:21 - +91 95150 92417: Thank you 🥰
# Happy Ugadi and Gudi padwa !
# 4/8/22, 10:57 - Praveena Vinod: Join Zoom Meetinghttps://us06web.zoom.us/j/82591146241?pwd=bmI4dGtVZnNjQ1ovOXFyVjhpNjIvQT09
# Meeting ID: 825 9114 6241
# Passcode: dsspr@kol
# 4/8/22, 10:57 - Praveena Vinod: Join using zoom link
# 4/11/22, 09:09 - Praveena Vinod: Session will start by 9.20am .
# 4/13/22, 09:08 - Praveena Vinod: Session will start by 9.20am .
# 4/13/22, 10:48 - Gourab Nath Praxis: Take a break for 10 mins. Will start at 11.
# 4/13/22, 10:54 - +91 98316 71628: Dear Students, This is a gentle reminder to kindly pay up your 2nd Installment fees on or before 15th April, 2022. You can mail your transaction details to admissions team mail id admissions@praxis.ac.in
# 4/13/22, 10:55 - +91 98316 71628: Please ignore this message incase you have paid. Thanks.
# 4/22/22, 10:59 - Praveena Vinod: Dear Students,
# Kindly be present in classroom sharp12.30 pm today for PY ET

# %% [markdown]
# ### List of unique members who have interacted at least once

# %%
fhand = open('Exam.txt',encoding = 'utf8')
unique_members=[]
for line in fhand: 
    line=line.strip()  #removing spaces
    if "-" in line:    #getting only lines which has member
        line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
       # print(line)
        if  ":" in line:
#                 print(line)
            line_chat = line[line.find("-")+1: line.find(":") ]  #extractuing only chat lines
           # print(line_chat)
            if line_chat not in unique_members: #finding if member is already present in unique_member list
                unique_members.append(line_chat) # appending unique member in list

print(unique_members) #printing list of unique members who have interacted at least once
# Out:
# [' Anushya Mahe Praxis', ' Praxis Madhuri Praxis Business School', ' +91 97736 87548', ' +91 6206 308 339', ' +91 75054 04417', ' +91 97906 93577', ' +91 88484 35019', ' +91 87575 13131', ' +91 98781 01877', ' +91 79905 19874', ' +91 98608 68194', ' +91 90796 99645', ' +91 94836 22622', ' +91 70342 08214', ' +91 99463 51164', ' +91 97411 21674', ' +91 95150 92417', ' +91 99788 89134', ' +91 98316 71628', ' Praveena Vinod', ' +91 97429 97747', ' +91 97269 95920', ' +91 95400 00588', ' Praxis Bhaskar', ' +91 96014 18197', ' +91 820 937 3714', ' Sushanta Praxis', ' +91 88600 61135', ' +91 96656 60920', ' +91 94447 66219', ' Praxis Aarti Madhavi', ' +91 99409 86538', ' +91 70301 03636', ' +91 94725 96200', ' +91 92233 84466', ' +91 79762 49627', ' +91 98319 48077', ' Teja Sai', ' +91 88846 30027', ' +91 97176 71005', ' Gourab Nath Praxis', ' Monali Sanjay Bendale']

# %% [markdown]
# ### Extracting entire conversation happened on a particular date

# %% [markdown]
# #### if we want conversation with member

# %%
def conversation_by_date(file, date):
    fhand = open(file,encoding = 'utf8')
    lst=[]
    for line in fhand: 
        line=line.strip() 
        #print(line)
        date_changed=date+","
        
        if line.startswith(date_changed):
            if "-" in line:    #getting only lines which has member
                line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
               # print(line)
                if  ":" in line:
                     #print(line)
                    line_chat = line[line.find("-")+1: ]  #extractuing only chat lines
                    lst.append(line_chat)
    return(lst)

# %%
conversation_by_date('Exam.txt', '2/2/22')
# Out:
# [' Praveena Vinod: Hi Evereyone,',
#  ' Praveena Vinod: Dear Students,',
#  ' Praveena Vinod: <Media omitted>',
#  ' Praveena Vinod: Please find below the google classroom link to upload the documents https://classroom.google.com/c/NDYzNjc4MTAxMDM2/a/NDYzODEwMjk5MDQ1/details',
#  ' Praveena Vinod: always use Praxis Email ID to access the emails and to attend classes',
#  ' Praveena Vinod: Any queries , Please call me or message me',
#  ' +91 98316 71628: Welcome Swati to the Bengaluru Batch.',
#  ' +91 96014 18197: Thank you so much',
#  ' +91 98316 71628: Guys Swati has joined your batch from today. Please give a warm welcome. Also, kindly introduce yourself Swati.',
#  ' +91 96014 18197: Hello everyone, i am new to the batch. I graduated in 2015 as a electronic and communication engineer. I bring 3.5 years of work experience. I am from Gujarat, Vadodara',
#  ' +91 99463 51164: Great to meet you',
#  ' +91 96014 18197: Thank you',
#  ' Praveena Vinod: Hi Swati , Your Praxis Email credentials will be shared with you shortly to your personal Email ID please',
#  ' +91 96014 18197: Okay',
#  ' Praveena Vinod: Swati i have shared a registration form kindly fill the form',
#  ' +91 96014 18197: Yes',
#  " +91 75054 04417: Hello ma'am,  is there any update on opening of college since the Kolkata campus is opening from 14th Feb?",
#  ' Praveena Vinod: Will update you by email']

# %% [markdown]
# ###### if we do not want member and want only chats

# %%
def conversation_by_date2(file, date):
    fhand = open(file,encoding = 'utf8')
    lst=[]
    for line in fhand: 
        line=line.strip() 
        #print(line)
        date_changed=date+","     
        if line.startswith(date_changed):
            if "-" in line:    #getting only lines which has member
                line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
               # print(line)
                if  ":" in line:
                     #print(line)
                    line_chat = line[line.find("-")+1: ]  #extractuing only chat lines
                    conversation=line_chat[line_chat.find(":")+1: ]
                    lst.append(conversation)
    return(lst)

# %%
conversation_by_date2('Exam.txt', '2/2/22')
# Out:
# [' Hi Evereyone,',
#  ' Dear Students,',
#  ' <Media omitted>',
#  ' Please find below the google classroom link to upload the documents https://classroom.google.com/c/NDYzNjc4MTAxMDM2/a/NDYzODEwMjk5MDQ1/details',
#  ' always use Praxis Email ID to access the emails and to attend classes',
#  ' Any queries , Please call me or message me',
#  ' Welcome Swati to the Bengaluru Batch.',
#  ' Thank you so much',
#  ' Guys Swati has joined your batch from today. Please give a warm welcome. Also, kindly introduce yourself Swati.',
#  ' Hello everyone, i am new to the batch. I graduated in 2015 as a electronic and communication engineer. I bring 3.5 years of work experience. I am from Gujarat, Vadodara',
#  ' Great to meet you',
#  ' Thank you',
#  ' Hi Swati , Your Praxis Email credentials will be shared with you shortly to your personal Email ID please',
#  ' Okay',
#  ' Swati i have shared a registration form kindly fill the form',
#  ' Yes',
#  " Hello ma'am,  is there any update on opening of college since the Kolkata campus is opening from 14th Feb?",
#  ' Will update you by email']

# %% [markdown]
# ### Extract all the posts done by a particular person

# %%
def conversation_by_person(file, person):
    fhand = open(file,encoding = 'utf8')
    lst_chat=[]
    modified_person = " " + person + ":"
    for line in fhand: 
        line=line.strip() 
        if "-" in line:    #getting only lines which has member
            line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
            # print(line)
            if  ":" in line:
                #print(line)
                line_chat = line[line.find("-")+1: ]  #extractuing only chat lines
    #             print(line_chat)
                
                if line_chat.startswith(modified_person):
                    chat= line_chat[line_chat.find(":")+1:]
                    lst_chat.append(chat)
    return(lst_chat)

# %%
conversation_by_person('Exam.txt', 'Gourab Nath Praxis')
# Out:
# [' Hi, everyone!',
#  ' Does this give you the chance start working with the IML assignment?',
#  ' Whichever team makes it todays gets 5 extra points...',
#  ' 👍🏼',
#  ' Whoever starts the project from the campus today gets the point...',
#  ' Btw 5 points in IML - no joke!!',
#  ' You can start as well',
#  ' Get the data from Savi',
#  ' Take a break for 10 mins. Will start at 11.']

# %%
conversation_by_person('Exam.txt', '+91 96014 18197')
# Out:
# [' Thank you so much',
#  ' Hello everyone, i am new to the batch. I graduated in 2015 as a electronic and communication engineer. I bring 3.5 years of work experience. I am from Gujarat, Vadodara',
#  ' Thank you',
#  ' Okay',
#  ' Yes',
#  ' Congratulations savi 🎉',
#  ' Welcome Teja 🎉',
#  ' Thank you sir 🙂']

# %% [markdown]
# ### Get the average length of messages posted by a particular person

# %% [markdown]
# #### if we are considering avg length by letters typed by person

# %%
def avg_length_by_person(file, person):
    count=0
    lst_chat=[]
    fhand = open(file,encoding = 'utf8')
    
    modified_person = " " + person + ":"
    for line in fhand: 
        line=line.strip() 
        if "-" in line:    #getting only lines which has member
            line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
            # print(line)
            if  ":" in line:
                #print(line)
                line_chat = line[line.find("-")+1: ]  #extractuing only chat lines
    #             print(line_chat)

                if line_chat.startswith(modified_person):
                    chat= line_chat[line_chat.find(":")+1:]
                    count+=1
                    trans = str.maketrans("",""," ")  #excluding spaces in messages
                    chat=chat.translate(trans) 
                    lst_chat.append(chat)

    letters_len= 0
    for message in lst_chat:
        letters_len= letters_len+len(message)
    avg_length=letters_len/ count
    return(avg_length)

# %%
avg_length_by_person('Exam.txt', 'Gourab Nath Praxis')
# Out:
# 29.444444444444443

# %% [markdown]
# #### if we are considering avg length by words typed by person

# %%
def avg_length_by_person(file, person):
    count=0 #initiated count for counting no of  msg
    lst_chat=[] #initialized to add every msg by particular person in the list
    fhand = open(file,encoding = 'utf8') #opening file
    modified_person = " " + person + ":" #modifying person name to identify specific chat line for further use
    for line in fhand: #for each line in file
        line=line.strip() #cutting spaces
        if "-" in line:    #getting only lines which has member
            line= line[line.find(":") +1:]  #getting only line which contain : once. so that we extract only chat lines further
            # print(line)
            if  ":" in line: #if again colon is contained in line
                #print(line)
                line_chat = line[line.find("-")+1: ]  #extracting only chat lines
    #             print(line_chat)

                if line_chat.startswith(modified_person):
                    chat= line_chat[line_chat.find(":")+1:]
    #                 print(chat)
                    lst_chat.append(chat)

                    count+=1
                    lst_chat.append(chat)

    words_count= 0 #initializing words count
    # print(lst_chat)
    for message in lst_chat: # for each msg in chat of specific person
        message=message.split()  #splitiing msg into words
        words_count=words_count+len(message) #counting words in each msg
    avg_len_by_words=words_count/count #calculating avg length of msg by words
    return(avg_len_by_words) #returning avg length of msg

# %%
avg_length_by_person('Exam.txt', 'Gourab Nath Praxis')
# Out:
# 14.0

# %% [markdown]
# ### Which part of the day (AM or PM) does this group experience most conversation?

# %%
def time_most_conversation(file):
    fhand = open(file,encoding = 'utf8') #opening file
    am_conversation=0
    pm_conversation=0
    for line in fhand:
        line=line.strip() 
    #     print(line)
        if line.count(":") >= 2:  #checking if colon exists in string at least 2 times
            if line.find('-')==15: #reconfirming that we are extracting only chat line
                line_chat=line            
        #         print(line_chat)
                time= line[line.find(', ')+2:line.find(":")] #extracting exact time in hour
                time=int(time) #converting string type of time into int
                if time < 12:
                    am_conversation +=1
                if time >= 12:
                    pm_conversation +=1
    if am_conversation>pm_conversation:
        print("This group experience most conversation in AM part of the day")
    elif pm_conversation>am_conversation:
        print("This group experience most conversation in PM part of the day")
    else:
        print("This group experience equal conversation in PM and AM part of the day")

# %%
time_most_conversation('Exam.txt')
# Out:
# This group experience most conversation in PM part of the day

# %% [markdown]
# ### frequency distribution of hours (considering only chats for frequency distribution)

# %%
def hours_distribution(file):
    fhand = open(file,encoding = 'utf8') #opening file
    count_hours = {}
    for line in fhand:
        line=line.strip() 
        #print(line)
        if line.count(":") >= 2:  #checking if colon exists in string at least 2 times
            line_chat=line
    #         print(line_chat)
            time = line[line.find(", ")+2:line.find("-")] #extracting exact time in hour with minutes
    #         print(time)
            time_hour= time[:time.find(":")] #extracting time with hour only as its 24 hour clock we don't need minute
    #         print(time_hour)
    #         print(len(time_hour))
            if len(time_hour) <= 2:     #ensuring its only time and nothing else because chat can contain as well
                count_hours[time_hour]=count_hours.get(time_hour,0) +1
                keys = list(count_hours.keys())
                keys.sort()

    for key in keys:
        print(key, count_hours[key])  #printing frequency dtsrtibution of each hour

# %%
hours_distribution('Exam.txt')
# Out:
# 02 1
# 08 8
# 09 13
# 10 69
# 11 15
# 12 64
# 13 33
# 14 84
# 15 67
# 16 51
# 17 40
# 18 6
# 19 1
# 20 7
# 21 1
# 22 1
# 23 1
